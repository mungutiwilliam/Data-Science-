# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
np.random.seed(7)

# %%
training_data = pd.read_csv('train.csv')

# %%
training_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
training_data.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
training_data.head().T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
training_data.head(30).T
# Out:
#                                   0   \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                             1   \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
training_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
training_data.tail(30).T
# Out:
#                                      861  \
# PassengerId                          862
# Survived                               0
# Pclass                                 2
# Name         Giles, Mr. Frederick Edward
# Sex                                 male
# Age                                 21.0
# SibSp                                  1
# Parch                                  0
# Ticket                             28134
# Fare                                11.5
# Cabin                                NaN
# Embarked                               S
#
#                                                            862  \
# PassengerId                                                863
# Survived                                                     1
# Pclass                                                       1
# Name         Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# Sex                                                     female
# ...

# %%
training_data.shape
# Out:
# (891, 12)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
training_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
training_data.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# # Check class distribution

# %%
# import the counter class

# %%
from collections import Counter

# %%
training_data['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
training_data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
training_data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
training_data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
training_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pylab as plt

# %%
# %matplotlib inline

# %%
sns.countplot(x ="Survived", data=training_data, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x= "Age", data=training_data, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Sex", data=training_data, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
training_data['Age'].mean()
# Out:
# 29.69911764705882

# %%
def impute_age(cols):
   
    Age = cols[0]
    Pclass = cols[1]
    
    
    if pd.isnull(Age):
        
        if Pclass == 1:
            return 37
        
        elif Pclass == 2:
            return 28
        
        else:
            return 25
    else:
        return Age

# %%
training_data['Age'] = training_data[['Age', 'Pclass']].apply(impute_age, axis = 1)

# %%
training_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
training_data.drop('Cabin', inplace= True , axis= 1)

# %%
training_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
training_data.sample(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 725          726         0       3
# 861          862         0       2
# 528          529         0       3
# 46            47         0       3
# 627          628         1       1
# 357          358         0       2
# 890          891         0       3
# 179          180         0       3
# 562          563         0       2
# 879          880         1       1
# 53            54         1       2
# 159          160         0       3
# 98            99         1       2
# 237          238         1       2
# 814          815         0       3
# 778          779         0       3
# 60            61         0       3
# 732          733         0       2
# 616          617         0       3
# 228          229         0       2
# 681          682         1       1
# 836          837         0       3
# 630          631         1       1
# 125          126         1       3
# 696          697         0       3
# ...

# %%
training_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
training_data.drop(['PassengerId','Name','Ticket'], axis=1, inplace=True)

# %%
training_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
sex= pd.get_dummies(training_data['Sex'], drop_first= True)
embark=pd.get_dummies(training_data['Embarked'], drop_first= True)

# %%
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
training_data.drop(['Sex', 'Embarked'], axis=1, inplace=True)

# %%
training_data= pd.concat([training_data, sex, embark], axis= 1)

# %%
training_data
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  1
# 1           1       1  38.0      1      0  71.2833     0  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  1
# 4           0       3  35.0      0      0   8.0500     1  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. ..
# 886         0       2  27.0      0      0  13.0000     1  0  1
# 887         1       1  19.0      0      0  30.0000     0  0  1
# 888         0       3  25.0      1      2  23.4500     0  0  1
# 889         1       1  26.0      0      0  30.0000     1  0  0
# 890         0       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 9 columns]

# %%
classes= Counter(training_data['Survived'].values)

# %%
classes.most_common()
# Out:
# [(0, 549), (1, 342)]

# %%
549+342
# Out:
# 891

# %%
(549/891)*100
# Out:
# 61.61616161616161

# %%
(342/891)*100
# Out:
# 38.38383838383838

# %%
#create dataframe for results

# %%
survival_dist= pd.DataFrame(classes.most_common(), columns=('Survival_state','Num_observations'))

# %%
survival_dist
# Out:
#    Survival_state  Num_observations
# 0               0               549
# 1               1               342

# %% [markdown]
# # split data

# %%
from sklearn.model_selection import train_test_split

# %%
X = training_data.drop(['Survived'], axis=1)

# %%
X
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         3  22.0      1      0   7.2500     1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0
# 2         3  26.0      0      0   7.9250     0  0  1
# 3         1  35.0      1      0  53.1000     0  0  1
# 4         3  35.0      0      0   8.0500     1  0  1
# ..      ...   ...    ...    ...      ...   ... .. ..
# 886       2  27.0      0      0  13.0000     1  0  1
# 887       1  19.0      0      0  30.0000     0  0  1
# 888       3  25.0      1      2  23.4500     0  0  1
# 889       1  26.0      0      0  30.0000     1  0  0
# 890       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 8 columns]

# %%
y = training_data['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
X_train.shape
# Out:
# (712, 8)

# %%
X_test.shape
# Out:
# (179, 8)

# %%
y_test.shape
# Out:
# (179,)

# %%
y_train.shape
# Out:
# (712,)

# %%
y.shape
# Out:
# (891,)

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report
from sklearn.linear_model import LogisticRegression
import wandb
import time

# %%
def train_eval_pipeline(model, train_data,test_data,name):
   
    wandb.init(project='ML for Titanic data', name=name)
   
    (X_train, y_train)= train_data
    (X_test, y_test)= test_data
    
    
    start= time.time()
    model.fit(X_train, y_train)
    end= time.time()-start
    prediction=model.predict(X_test)
    
    wandb.log({"accuracy": accuracy_score(y_test, prediction)*100, "precision":precision_recall_fscore_support(y_test,prediction, average='macro')[0],"recall":precision_recall_fscore_support(y_test,prediction, average='macro')[1],"training_time": end})
    print("Accuracy score of the Logistic Regression Classifire with default hyperparameter values {0:2f}%".format(accuracy_score(y_test,prediction)*100.))
    print("\n")
    print("---Classification report of the Logistic Regression Classifier with default parameter values ---")
    print("\n")
    print(classification_report(y_test,prediction, target_names=["Dead","Survived"]))

# %%
logreg=LogisticRegression()

# %%
train_eval_pipeline(logreg, (X_train,y_train),(X_test,y_test), "Logistic_Regression_Titanic_Data")
# Out:
# wandb: Currently logged in as: wmunguti (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">Logistic_Regression_Titanic_Data</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/wmunguti/ML%20for%20Titanic%20data" target="_blank">https://wandb.ai/wmunguti/ML%20for%20Titanic%20data</a><br/>
#                 Run page: <a href="https://wandb.ai/wmunguti/ML%20for%20Titanic%20data/runs/1fr6887f" target="_blank">https://wandb.ai/wmunguti/ML%20for%20Titanic%20data/runs/1fr6887f</a><br/>
#                 Run data is saved locally in <code>C:\Users\hp\Desktop\Artificial inteligence labs\wandb\run-20210925_230657-1fr6887f</code><br/><br/>
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
penalty = ["l1","l2"]

# %%
C=[0.8,0.9,1.0]

# %%
tol=[0.1,0.01,0.0001]

# %%
max_iter=[100,150,200,250]

# %%
param_grid= dict(penalty=penalty,C=C,tol=tol,max_iter=max_iter)

# %%
random_model= RandomizedSearchCV(estimator=logreg, param_distributions=param_grid, cv=5)

# %%
random_model_result= random_model.fit(X_train,y_train)

# %%
best_score, best_params=random_model_result.best_score_,random_model_result.best_params_

# %%
print ('Best score: %.2f using %s'%(best_score*100.,best_params))
# Out:
# Best score: 80.76 using {'tol': 0.0001, 'penalty': 'l2', 'max_iter': 250, 'C': 0.9}

# %%
config= wandb.config

# %%
config.tol=0.01

# %%
config.penalty="l2"

# %%
config.C=0.9

# %%
logreg=LogisticRegression(tol=config.tol, penalty=config.penalty, max_iter=100,C=config.C)

# %%
logreg
# Out:
# LogisticRegression(C=0.9, tol=0.01)

# %%
train_eval_pipeline(logreg, (X_train,y_train),(X_test,y_test), "Logistic-Regression-Random-Search")
# Out:
# Finishing last run (ID:11hfoj8w) before initializing another...
# <br/>Waiting for W&B process to finish, PID 13096<br/>Program ended successfully.
# ...
# Find user logs for this run at: <code>C:\Users\hp\Desktop\Artificial inteligence labs\wandb\run-20210925_230713-11hfoj8w\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\hp\Desktop\Artificial inteligence labs\wandb\run-20210925_230713-11hfoj8w\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>accuracy</td><td>82.12291</td></tr><tr><td>precision</td><td>0.8251</td></tr><tr><td>recall</td><td>0.81319</td></tr><tr><td>training_time</td><td>0.08704</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...
